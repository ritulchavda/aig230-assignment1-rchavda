# %% [markdown]
# # Lab 1 – Python Fundamentals Review
# Learning Objectives
#
# By the end of this lab, you should be able to:
#
# - Work confidently with Python data types and structures
#
# - Use control flow to write basic programs
#
# - Write reusable functions and simple classes
#
# - Manipulate lists, dictionaries, and matrices
#
# - Apply Python fundamentals in preparation for PyTorch

# %% [markdown]
# ## Variables and Basic Data Types

# %%
# Integer
x = 10

# Float
y = 3.14

# String
name = "AIG 230"

# Boolean
is_fun = True

print(x, y, name, is_fun)
# Out:
# 10 3.14 AIG 230 True

# %% [markdown]
# ## Lists

# %%
numbers = [1, 2, 3, 4, 5]
words = ["nlp", "python", "pytorch"]

print(numbers)
print(words)
# Out:
# [1, 2, 3, 4, 5]
# ['nlp', 'python', 'pytorch']

# %% [markdown]
# ### Common List Operations

# %%
numbers.append(6)
numbers.remove(3)

print(numbers)
print(numbers[0])      # first element
print(numbers[-1])     # last element
# Out:
# [1, 2, 4, 5, 6]
# 1
# 6

# %% [markdown]
# ### Looping Through a List

# %%
for word in words:
    print(word.upper())
# Out:
# NLP
# PYTHON
# PYTORCH

# %%
# TODO
"""Create a list of 5 numbers and print their squares."""

square_list = [2,3,4,5,6]
for i in square_list:
    print(str(i) + ' : ' + str(i**2))
# Out:
# 2 : 4
# 3 : 9
# 4 : 16
# 5 : 25
# 6 : 36

# %% [markdown]
# ## Dictionaries

# %%
# Dictionaries store key–value pairs
student = {
    "name": "Jessica",
    "course": "AIG 230",
    "year": 2026
}

print(student)
print(student["course"])
# Out:
# {'name': 'Jessica', 'course': 'AIG 230', 'year': 2026}
# AIG 230

# %% [markdown]
# ### Modifying Dictionaries

# %%
student["grade"] = "A"
student["year"] = 2027

print(student)
# Out:
# {'name': 'Jessica', 'course': 'AIG 230', 'year': 2027, 'grade': 'A'}

# %% [markdown]
# ### Looping Through a Dictionary

# %%
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Jessica
# course : AIG 230
# year : 2027
# grade : A

# %%
# TODO
""" Create a dictionary describing the courses you are taking this semester
(keys: course_name, code, time, grade)."""

courses = [{
    "course_name": "Capstone Project",
    "code": "AIG 200",
    "time": "15 Jan 2025",
    "grade": 4
}, {
    "course_name": "Computer Vision",
    "code": "AIG 210",
    "time": "15 Jan 2025",
    "grade": 4
}, {
    "course_name": "Deep Learning",
    "code": "AIG 220",
    "time": "15 Jan 2025",
    "grade": 4
}, {
    "course_name": "Natural Language Processing",
    "code": "AIG 230",
    "time": "15 Jan 2025",
    "grade": 4
}, {
    "course_name": "Robotics",
    "code": "AIG 240",
    "time": "15 Jan 2025",
    "grade": 4
}, {
    "course_name": "Work Term Preparation",
    "code": "WTP 100",
    "time": "15 Jan 2025",
    "grade": 4
}]

i = 1
for course in courses:
    print("Course Name: ", course["course_name"], ", Code: ", course["code"], ", Time: ", course["time"], ", Grade: ", course["grade"])
    i += 1
# Out:
# Course Name:  Capstone Project , Code:  AIG 200 , Time:  15 Jan 2025 , Grade:  4
# Course Name:  Computer Vision , Code:  AIG 210 , Time:  15 Jan 2025 , Grade:  4
# Course Name:  Deep Learning , Code:  AIG 220 , Time:  15 Jan 2025 , Grade:  4
# Course Name:  Natural Language Processing , Code:  AIG 230 , Time:  15 Jan 2025 , Grade:  4
# Course Name:  Robotics , Code:  AIG 240 , Time:  15 Jan 2025 , Grade:  4
# Course Name:  Work Term Preparation , Code:  WTP 100 , Time:  15 Jan 2025 , Grade:  4

# %% [markdown]
# # Matrices and Nested Lists

# %%
# In Python, matrices are often represented as lists of lists.
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(matrix)
print(matrix[0])
print(matrix[1][2])  # row 2, column 3
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# [1, 2, 3]
# 6

# %% [markdown]
# ### Looping Through a Matrix

# %%
for row in matrix:
    for value in row:
        print(value, end=" ")
    print()
# Out:
# 1 2 3
# 4 5 6
# 7 8 9

# %%
# TODO
""" Create a 2×3 matrix and print all values."""

matrix = [
    [1, 2, 3],
    [4, 5, 6]
]

print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %% [markdown]
# # Basic Operations

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a ** b)  # exponentiation
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1000

# %% [markdown]
# ### Operations on Lists

# %%
nums = [1, 2, 3]
nums_times_two = [n * 2 for n in nums]

print(nums_times_two)
# Out:
# [2, 4, 6]

# %% [markdown]
# # Conditional Statements (if / elif / else)

# %%
score = 85

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
else:
    grade = "C"

print("Grade:", grade)
# Out:
# Grade: B

# %% [markdown]
# # For Loops

# %%
for i in range(5):
    print("Iteration:", i)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %% [markdown]
# ### Loop with Condition

# %%
for num in range(10):
    if num % 2 == 0:
        print(num, "is even")
# Out:
# 0 is even
# 2 is even
# 4 is even
# 6 is even
# 8 is even

# %% [markdown]
# # Functions

# %%
# Functions help you reuse code.

def greet(name):
    return f"Hello, {name}!"

print(greet("AIG 230"))
# Out:
# Hello, AIG 230!

# %%
# Function with Multiple Arguments

def add(a, b):
    return a + b

result = add(3, 5)
print(result)
# Out:
# 8

# %%
# TODO
""" Write a function that returns the square of a number"""

def give_me_square_of(a):
    return a**2

print(give_me_square_of(10))
print(give_me_square_of(5))
# Out:
# 100
# 25

# %% [markdown]
# # Classes and Objects

# %%
# Classes allow you to model real-world objects.
class Student:
    def __init__(self, name, course):
        self.name = name
        self.course = course

    def introduce(self):
        return f"My name is {self.name} and I am enrolled in {self.course}"

# %%
student1 = Student("Jessica", "AIG 230")
print(student1.introduce())
# Out:
# My name is Jessica and I am enrolled in AIG 230

# %% [markdown]
# # Putting It All Together

# %%
# TODO
""" Create a class called courses_winter 2026
with attributes course_name, code, time, grade and a method to display course info."""

class courses_winter_2026:
    def __init__(self, course_name, code, time, grade):
        self.course_name = course_name
        self.code = code
        self.time = time
        self.grade = grade

    def display_course_info(self):
        print(f"Course Name: {self.course_name}, Course Code: {self.code}, Time: {self.time}, Grade: {self.grade}")


course = courses_winter_2026(
    "Natural Language Processing",
    "AIG 230",
    "15 Jan 2025",
    "4"
)

course.display_course_info()
# Out:
# Course Name: Natural Language Processing, Course Code: AIG 230, Time: 15 Jan 2025, Grade: 4

# %%
# TODO
""" Create three instances of the courses_winter 2026 class and display their info."""

courseOne = courses_winter_2026(
    "Natural Language Processing",
    "AIG 230",
    "15 Jan 2025",
    "4"
)

courseTwo = courses_winter_2026(
    "Capstone Project",
    "AIG 200",
    "15 Jan 2025",
    "4"
)

courseThree = courses_winter_2026(
    "Robotics",
    "AIG 240",
    "15 Jan 2025",
    "4"
)

courseOne.display_course_info()
print()
courseOne.display_course_info()
print()
courseOne.display_course_info()
# Out:
# ' Create three instances of the courses_winter 2026 class and display their info.'
